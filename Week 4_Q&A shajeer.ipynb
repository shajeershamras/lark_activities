# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mdb=pd.read_csv(r'C:\Users\user\Desktop\Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv')
mdb.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Churn count comparison with respect to gender

# %%
plt.figure(figsize=(5,5))
sns.countplot( x='gender',hue='Churn',data= mdb) 
plt.title('Churn count respect to the gender',fontweight="bold")
plt.grid(linestyle="--")  
plt.show()

# %% [markdown]
# # Number of female senior citizens in dataset

# %%
sdb1=mdb[(mdb['gender']=='Female') & (mdb['SeniorCitizen']==1)]
sdb1['gender'].count()
plt.figure(figsize=(6,6))
sns.countplot( x='gender',hue='SeniorCitizen',data=sdb1) 
plt.title("Count of female senior citizens ")
# Out:
# Text(0.5, 1.0, 'Count of female senior citizens ')

# %% [markdown]
# # Comparison of 'tenure' with 'Total Charges

# %%
plt.figure(figsize=(8,8))
plt.scatter(mdb['tenure'] , mdb['TotalCharges'] , s=10 , c='green')
plt.title("Tenure VS Total charges",fontweight="bold")
plt.xlabel('Tenure')
plt.ylabel('Total Charges')
# Out:
# Text(0, 0.5, 'Total Charges')

# %% [markdown]
# # Most preferred contract by Senior Citizens

# %%
plt.figure(figsize=(8,8))
sns.countplot(sdb1['Contract'])
plt.title('Contract preference of SeniorCitizens', fontsize=15)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Contract preference of SeniorCitizens')

# %% [markdown]
# # Findings on Payment Method

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='PaymentMethod', hue='gender' , data=mdb)
plt.title("Payment method VS Gender" , fontsize='14')
# Out:
# Text(0.5, 1.0, 'Payment method VS Gender')

# %%
plt.figure(figsize=(8,8))
sns.countplot(mdb['PaymentMethod'])
plt.title('Payment Methods')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Payment Methods')

# %%
plt.figure(figsize=(8,8))
sns.countplot(sdb1['PaymentMethod'])
plt.title('PaymentMethod preference of SeniorCitizen' , fontsize=15)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'PaymentMethod preference of SeniorCitizen')
